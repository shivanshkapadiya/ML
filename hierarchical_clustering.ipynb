# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanshkapadiya/ML/blob/main/hierarchical_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Create synthetic dataset
X, _ = make_blobs(n_samples=50, centers=4, cluster_std=1.0, random_state=42)

plt.scatter(X[:, 0], X[:, 1])
plt.title("Synthetic Data")
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
# Perform hierarchical clustering
Z = linkage(X, method='average')  # Try 'single', 'complete', 'average' too

# Plot the dendrogram
plt.figure(figsize=(18, 8))
dendrogram(Z)
plt.title("Dendrogram")
plt.xlabel("Data Points")
plt.ylabel("Distance")
plt.show()
