# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanshkapadiya/ML/blob/main/myfristML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
list=[34,44,232,232,455,22,678,33,11]
rest=pd.Series(list)
print(" Series=\n",rest)
# Out:
#  Series=
#  0     34
# 1     44
# 2    232
# 3    232
# 4    455
# 5     22
# 6    678
# 7     33
# 8     11
# dtype: int64

# %%
import numpy as np
arr=np.array((1,2,3,4,5,6,7))
print("array=",arr)
print(type(arr))
# Out:
# array= [1 2 3 4 5 6 7]
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt
import numpy as np

xplt=np.array([0,40])
yplt=np.array([0,117])
plt.title("Line Plot")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")

plt.plot(xplt,yplt)
plt.show()

# %%
print("hi")
# Out:
# hi
